# %%
import geopandas
import geoplot

world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)
boroughs = geopandas.read_file(
    geoplot.datasets.get_path('nyc_boroughs')
)
collisions = geopandas.read_file(
    geoplot.datasets.get_path('nyc_injurious_collisions')
)

# %%
europe = world.query('continent == "Europe"')
ax = geoplot.cartogram(
    europe, scale='pop_est', limits=(0.2, 1),
    edgecolor='None', figsize=(60,70)
)
geoplot.polyplot(europe, edgecolor='gray', ax=ax)

# %%
ax = geoplot.voronoi(
    collisions.head(1000), projection=geoplot.crs.AlbersEqualArea(),
    clip=boroughs.simplify(0.001),
    hue='NUMBER OF PERSONS INJURED', cmap='Reds',
    legend=True,
    edgecolor='white'
)
geoplot.polyplot(boroughs, edgecolor='black', zorder=1, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-258969a692e5> in <module>
#       4     hue='NUMBER OF PERSONS INJURED', cmap='Reds',
#       5     legend=True,
# ----> 6     edgecolor='white'
#       7 )
#       8 geoplot.polyplot(boroughs, edgecolor='black', zorder=1, ax=ax)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geoplot/geoplot.py in voronoi(df, projection, clip, hue, cmap, norm, scheme, legend, legend_kwargs, legend_labels, legend_values, extent, edgecolor, figsize, ax, **kwargs)
#    1654         **kwargs
#    1655     )
# -> 1656     return plot.draw()
#    1657
#    1658
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geoplot/geoplot.py in draw(self)
#    1619                 return ax
#    1620
# -> 1621             geoms = build_voronoi_polygons(self.df)
#    1622             # Must take the .values of the output GeoDataFrame because assign is index-aligned.
#    1623             # So self.df can have any index. But set_clip constructs a new GeoSeries with a fresh
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geoplot/ops.py in build_voronoi_polygons(df)
#     189     if len(geom) != len(np.unique(geom, axis=0)):
#     190         raise ValueError(
# --> 191             f'The input data contains duplicate coordinates, which Voronoi tessellation does not '
#     192             f'support. To fix this error, make sure that ever record in your dataset has a unique '
#     193             f'coordinate value.'
#
# ValueError: The input data contains duplicate coordinates, which Voronoi tessellation does not support. To fix this error, make sure that ever record in your dataset has a unique coordinate value.
